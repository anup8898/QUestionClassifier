# %% [markdown]
# <a href="https://colab.research.google.com/github/anup8898/QUestionClassifier/blob/main/question_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
import pandas as pd
import seaborn as sns
import pandas as pd
import numpy as np
import preprocess_kgptalkie as ps
import re

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d15fc84b-c519-46f1-99dd-c8d770d1fa11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d15fc84b-c519-46f1-99dd-c8d770d1fa11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Indian_Economy_Objective_Questions_SmartPrep.txt to Indian_Economy_Objective_Questions_SmartPrep.txt
# Saving Indian_Geography_Objective_Questions_SmartPrep.txt to Indian_Geography_Objective_Questions_SmartPrep.txt
# Saving 1500-History-Questions-Answers-For-CDS-AFCAT-NDA-TA-1.txt to 1500-History-Questions-Answers-For-CDS-AFCAT-NDA-TA-1.txt

# %%
df = pd. read_csv("1500-History-Questions-Answers-For-CDS-AFCAT-NDA-TA-1.txt", sep="\t")

# %%
econ=pd. read_csv("Indian_Economy_Objective_Questions_SmartPrep.txt", sep="\t",header=None,error_bad_lines=False,encoding='cp1252')
# Out:
# b'Skipping line 4: expected 1 fields, saw 2\nSkipping line 5: expected 1 fields, saw 2\nSkipping line 6: expected 1 fields, saw 2\nSkipping line 7: expected 1 fields, saw 2\nSkipping line 100: expected 1 fields, saw 7\nSkipping line 148: expected 1 fields, saw 3\nSkipping line 149: expected 1 fields, saw 2\nSkipping line 150: expected 1 fields, saw 2\nSkipping line 151: expected 1 fields, saw 2\nSkipping line 170: expected 1 fields, saw 2\nSkipping line 171: expected 1 fields, saw 2\nSkipping line 190: expected 1 fields, saw 2\nSkipping line 191: expected 1 fields, saw 2\nSkipping line 231: expected 1 fields, saw 2\nSkipping line 232: expected 1 fields, saw 2\nSkipping line 233: expected 1 fields, saw 2\nSkipping line 234: expected 1 fields, saw 2\nSkipping line 235: expected 1 fields, saw 2\nSkipping line 237: expected 1 fields, saw 5\nSkipping line 275: expected 1 fields, saw 2\nSkipping line 276: expected 1 fields, saw 2\nSkipping line 277: expected 1 fields, saw 2\nSkipping line 
# ...

# %%
geog=pd. read_csv("Indian_Geography_Objective_Questions_SmartPrep.txt", sep="\t",header=None,error_bad_lines=False,encoding='cp1252')
# Out:
# b'Skipping line 86: expected 1 fields, saw 2\nSkipping line 131: expected 1 fields, saw 2\nSkipping line 132: expected 1 fields, saw 2\nSkipping line 133: expected 1 fields, saw 2\nSkipping line 134: expected 1 fields, saw 7\nSkipping line 303: expected 1 fields, saw 2\nSkipping line 304: expected 1 fields, saw 2\nSkipping line 305: expected 1 fields, saw 2\nSkipping line 306: expected 1 fields, saw 2\nSkipping line 318: expected 1 fields, saw 2\nSkipping line 319: expected 1 fields, saw 2\nSkipping line 320: expected 1 fields, saw 2\nSkipping line 321: expected 1 fields, saw 2\nSkipping line 323: expected 1 fields, saw 2\nSkipping line 334: expected 1 fields, saw 2\nSkipping line 336: expected 1 fields, saw 2\nSkipping line 337: expected 1 fields, saw 2\nSkipping line 339: expected 1 fields, saw 2\nSkipping line 340: expected 1 fields, saw 2\nSkipping line 342: expected 1 fields, saw 2\nSkipping line 343: expected 1 fields, saw 2\nSkipping line 345: expected 1 fields, saw 2\nSkippin
# ...

# %%
econ
# Out:
#                                                       0
# 0        1. National Development Council was set up in:
# 1                                              Ans: (d)
# 2     2. Economic Planning is a subject: [Asstt Grad...
# 3                                 (a) in the Union List
# 4                                 (b) in the State List
# ...                                                 ...
# 4073                                         (1) Only A
# 4074                                         (2) Only B
# 4075                                         (3) Only C
# 4076                                     (4) Both A & B
# 4077                         (5) None of these Ans: (1)
#
# [4078 rows x 1 columns]

# %%
df
# Out:
#      1. Which of the following Vedas deals with magic spells and witchcraft? (a) Rigveda
# 0                                         (b) Samaveda
# 1                                        (c) Yajurveda
# 2                                      (d) Atharvaveda
# 3                                             Ans: (d)
# 4                                             SSB-CRACK
# ...                                                 ...
# 2740  453. 'Abhijnanasakuntalam' has been reckoned a...
# 2741                                      (b) Kalidasa
# 2742                                    (c) Asvaghosha
# 2743                                       (d) Sudraka
# 2744                                           Ans: (b)
#
# [2745 rows x 1 columns]

# %%
df.columns=['Content']

# %%
econ.columns=['Content']

# %%
geog.columns=['Content']

# %%
df
# Out:
#                                                 Content
# 0                                         (b) Samaveda
# 1                                        (c) Yajurveda
# 2                                      (d) Atharvaveda
# 3                                             Ans: (d)
# 4                                             SSB-CRACK
# ...                                                 ...
# 2740  453. 'Abhijnanasakuntalam' has been reckoned a...
# 2741                                      (b) Kalidasa
# 2742                                    (c) Asvaghosha
# 2743                                       (d) Sudraka
# 2744                                           Ans: (b)
#
# [2745 rows x 1 columns]

# %%
df.Content=df.Content.astype('str')

# %%
econ.Content=econ.Content.astype('str')

# %%
geog.Content=geog.Content.astype('str')

# %%
df
# Out:
#                                                 Content
# 0                                         (b) Samaveda
# 1                                        (c) Yajurveda
# 2                                      (d) Atharvaveda
# 3                                             Ans: (d)
# 4                                             SSB-CRACK
# ...                                                 ...
# 2740  453. 'Abhijnanasakuntalam' has been reckoned a...
# 2741                                      (b) Kalidasa
# 2742                                    (c) Asvaghosha
# 2743                                       (d) Sudraka
# 2744                                           Ans: (b)
#
# [2745 rows x 1 columns]

# %%
His_df = df.loc[df['Content'].str.contains("\?", case=False)]

# %%
econ_df = econ.loc[econ['Content'].str.contains("\?", case=False)]

# %%
geog_df = geog.loc[geog['Content'].str.contains("\?", case=False)]

# %%
His_df
# Out:
#                                                 Content
# 22    5. Which of the following contains the famous ...
# 60    12. Which of the following civilisations is ne...
# 66    13. Of the following scholars who was the firs...
# 126   22. Which of the following metals was not know...
# 137   24. At which of the following Harappan sites h...
# ...                                                 ...
# 2609  431. What is the name of the preaching mudra o...
# 2615    432. What was the original name of Euthydemia?
# 2620          433. In whose coins was the wheel round?
# 2626  434. In whose reign did the visit of Saint Tho...
# 2735  452. Who, among the following rulers, organise...
#
# [146 rows x 1 columns]

# %%
His_df['Subject']='History'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
econ_df['Subject']='Econ'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
geog_df['Subject']='Geog'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
His_df
# Out:
#                                                 Content  Subject
# 22    5. Which of the following contains the famous ...  History
# 60    12. Which of the following civilisations is ne...  History
# 66    13. Of the following scholars who was the firs...  History
# 126   22. Which of the following metals was not know...  History
# 137   24. At which of the following Harappan sites h...  History
# ...                                                 ...      ...
# 2609  431. What is the name of the preaching mudra o...  History
# 2615    432. What was the original name of Euthydemia?   History
# 2620          433. In whose coins was the wheel round?   History
# 2626  434. In whose reign did the visit of Saint Tho...  History
# 2735  452. Who, among the following rulers, organise...  History
#
# [146 rows x 2 columns]

# %%
His_df.reset_index(drop=True)
# Out:
#                                                Content  Subject
# 0    5. Which of the following contains the famous ...  History
# 1    12. Which of the following civilisations is ne...  History
# 2    13. Of the following scholars who was the firs...  History
# 3    22. Which of the following metals was not know...  History
# 4    24. At which of the following Harappan sites h...  History
# ..                                                 ...      ...
# 141  431. What is the name of the preaching mudra o...  History
# 142    432. What was the original name of Euthydemia?   History
# 143          433. In whose coins was the wheel round?   History
# 144  434. In whose reign did the visit of Saint Tho...  History
# 145  452. Who, among the following rulers, organise...  History
#
# [146 rows x 2 columns]

# %%
econ_df.reset_index(drop=True)
# Out:
#                                                Content Subject
# 0    7. Which of the following statements is correc...    Econ
# 1        13. Who is called the 'Father of Economics' ?    Econ
# 2                                      Indian economy?    Econ
# 3    20. Which of the following are not correct ass...    Econ
# 4    21. Who is the Deputy Chairman of Planning Com...    Econ
# ..                                                 ...     ...
# 300      71. What does S & P 500 relate to? [IAS 2008]    Econ
# 301  72. Which one amongst the following has the la...    Econ
# 302  73. Basel II relates to which one of the follo...    Econ
# 303  74. Tarapore Committee was associated with whi...    Econ
# 304  75. A National Development Fund was created by...    Econ
#
# [305 rows x 2 columns]

# %%
geog_df.reset_index(drop=True)
# Out:
#                                                Content Subject
# 0    1. Which state has smallest land area? [IAS 2003]    Geog
# 1    4. Among the following Union Territories of In...    Geog
# 2    5. Which one of the following pairs is correct...    Geog
# 3    11. Which foreign country is closest to Andama...    Geog
# 4    12. Which one of the following States shares b...    Geog
# ..                                                 ...     ...
# 564  586. Indian Standard Time (IST) is determined ...    Geog
# 565  587. Which one of the following Indian towns h...    Geog
# 566  588. Which of the following States has the mos...    Geog
# 567  595. Which of the following is not a seed born...    Geog
# 568                             rivers is not correct?    Geog
#
# [569 rows x 2 columns]

# %%
frames = [His_df,econ_df,geog_df]

# %%
main_df=pd.concat(frames)

# %%
main_df
# Out:
#                                                 Content  Subject
# 22    5. Which of the following contains the famous ...  History
# 60    12. Which of the following civilisations is ne...  History
# 66    13. Of the following scholars who was the firs...  History
# 126   22. Which of the following metals was not know...  History
# 137   24. At which of the following Harappan sites h...  History
# ...                                                 ...      ...
# 8177  586. Indian Standard Time (IST) is determined ...     Geog
# 8182  587. Which one of the following Indian towns h...     Geog
# 8187  588. Which of the following States has the mos...     Geog
# 8222  595. Which of the following is not a seed born...     Geog
# 8248                             rivers is not correct?     Geog
#
# [1020 rows x 2 columns]

# %%
final1=main_df.reset_index(drop=True)

# %%
def get_clean(x):
    x = str(x).lower().replace('\\', '').replace('_', ' ')
    x = ps.cont_exp(x)
    x = ps.remove_emails(x)
    x = ps.remove_urls(x)
    x = ps.remove_html_tags(x)
    x = ps.remove_rt(x)
    x = ps.remove_accented_chars(x)
    x = ps.remove_special_chars(x)
    x = re.sub("(.)\\1{2,}", "\\1", x)
    return x

# %%
pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# ...
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to /tmp/pip-req-build-0g6qd4sp
#   Running command git clone -q https://github.com/laxmimerit/preprocess_kgptalkie.git /tmp/pip-req-build-0g6qd4sp
# ...
#   Created wheel for preprocess-kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=11754 sha256=ab0ea8d3adbbc5746c5ce572e533077e972ab2e709153a5581f15fcedb75c2b7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ykwyd1q0/wheels/0d/b3/29/bfe3deffda68980088d17b81331be6667e837ffb4a071bae82
# Successfully built preprocess-kgptalkie
# ...
#   Attempting uninstall: preprocess-kgptalkie
#     Found existing installation: preprocess-kgptalkie 0.1.3
#     Uninstalling preprocess-kgptalkie-0.1.3:
#       Successfully uninstalled preprocess-kgptalkie-0.1.3
# ...

# %%
final1['Content'] =final1['Content'].apply(lambda x:get_clean(x))

# %%
final1
# Out:
#                                                 Content  Subject
# 0     5 which of the following contains the famous g...  History
# 1     12 which of the following civilisations is net...  History
# 2     13 of the following scholars who was the first...  History
# 3     22 which of the following metals was not known...  History
# 4     24 at which of the following harappan sites ha...  History
# ...                                                 ...      ...
# 1015  586 indian standard time ist is determined acc...     Geog
# 1016  587 which one of the following indian towns ha...     Geog
# 1017  588 which of the following states has the most...     Geog
# 1018  595 which of the following is not a seed borne...     Geog
# 1019                              rivers is not correct     Geog
#
# [1020 rows x 2 columns]

# %%
 from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer()

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
clf1 = LogisticRegression(multi_class='multinomial', random_state=1)
clf2 = RandomForestClassifier(n_estimators=50, random_state=1)
clf4 = AdaBoostClassifier()

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=15,weights='distance')

# %%
eclf = VotingClassifier(estimators=[('lr', clf1), ('rf', clf2), ('gnb', clf3)],voting='hard')

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
from sklearn.metrics import classification_report

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
stopwords=set(STOPWORDS)

# %%
c=1
plt.figure(figsize=(10, 14))
for x in final1['Subject'].unique():
    plt.subplot(3,1,c)
    wc = WordCloud(background_color="white", max_words=100, stopwords=stopwords,
                   max_font_size=40, random_state=42).generate(final1[final1['Subject']==x]['Content'].to_string())  
   
    
    plt.imshow(wc)
    plt.title(x,fontsize='24',fontweight='20')
    plt.axis("off")
    c+=1

# %%
y=final1.Subject

# %%
X=final1['Content']

# %%
X=tfidf.fit_transform(X)

# %%
X
# Out:
# <1020x2619 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12557 stored elements in Compressed Sparse Row format>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train1, X_val1, y_train1, y_val1 = train_test_split(X_train, y_train, test_size=0.25, random_state=5)

# %%
clf=GradientBoostingClassifier()

# %%
neigh.fit(X_train1,y_train1)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#                      weights='distance')

# %%
ypred=neigh.predict(X_val1)

# %%
print(classification_report(y_val1,ypred))
# Out:
#               precision    recall  f1-score   support
#
#         Econ       0.75      0.50      0.60        54
#         Geog       0.69      0.92      0.79       115
#      History       0.80      0.34      0.48        35
#
#     accuracy                           0.71       204
#    macro avg       0.75      0.59      0.62       204
# weighted avg       0.73      0.71      0.69       204
